# %% [markdown]
# # 🐍 Python Grundlagen - Praktische Übungen
#
# In diesem Notebook kannst du die Grundlagen praktisch üben!
#
# ## 📝 Variablen und Datentypen

# %%
# Übung 1: Erstelle Variablen
name = "Max"
alter = 25
groesse = 1.75
ist_student = True

print(f"Name: {name}")
print(f"Alter: {alter}")
print(f"Größe: {groesse}m")
print(f"Student: {ist_student}")

# %% [markdown]
# ### ✏️ Deine Aufgabe:
# Erstelle Variablen für deine eigenen Daten und gib sie aus!

# %%
# Dein Code hier:

# %% [markdown]
# ## ➕ Operatoren

# %%
# Übung 2: Rechnen
a = 10
b = 3

print(f"{a} + {b} = {a + b}")
print(f"{a} - {b} = {a - b}")
print(f"{a} * {b} = {a * b}")
print(f"{a} / {b} = {a / b}")
print(f"{a} // {b} = {a // b}")
print(f"{a} % {b} = {a % b}")
print(f"{a} ** {b} = {a ** b}")

# %% [markdown]
# ### ✏️ Deine Aufgabe:
# Berechne die Fläche eines Kreises mit Radius 5. (Fläche = π * r²)

# %%
# Dein Code hier:
PI = 3.14159
radius = 5
# ...

# %% [markdown]
# ## 📝 Strings

# %%
# Übung 3: String-Methoden
text = "Python ist toll"

print(f"Original: {text}")
print(f"Großbuchstaben: {text.upper()}")
print(f"Kleinbuchstaben: {text.lower()}")
print(f"Länge: {len(text)}")
print(f"Ersetzt: {text.replace('toll', 'super')}")

# %% [markdown]
# ### ✏️ Deine Aufgabe:
# Nimm den String "Hallo Welt" und:
# - Ersetze "Welt" mit deinem Namen
# - Wandle in Großbuchstaben um
# - Finde die Länge

# %%
# Dein Code hier:

# %% [markdown]
# ## 📋 Listen

# %%
# Übung 4: Listen
fruechte = ["Apfel", "Banane", "Kirsche"]

print(f"Original: {fruechte}")

# Hinzufügen
fruechte.append("Dattel")
print(f"Nach append: {fruechte}")

# Entfernen
fruechte.remove("Banane")
print(f"Nach remove: {fruechte}")

# Sortieren
fruechte.sort()
print(f"Sortiert: {fruechte}")

# %% [markdown]
# ### ✏️ Deine Aufgabe:
# Erstelle eine Liste mit 5 Zahlen, berechne die Summe und den Durchschnitt.

# %%
# Dein Code hier:

# %% [markdown]
# ## 📚 Dictionaries

# %%
# Übung 5: Dictionaries
person = {
    "name": "Max",
    "alter": 25,
    "stadt": "Berlin"
}

print(f"Name: {person['name']}")
print(f"Alter: {person['alter']}")

# Hinzufügen
person["beruf"] = "Programmierer"

# Alle Keys und Values
for key, value in person.items():
    print(f"{key}: {value}")

# %% [markdown]
# ### ✏️ Deine Aufgabe:
# Erstelle ein Dictionary für ein Produkt mit: name, preis, anzahl, kategorie

# %%
# Dein Code hier:

# %% [markdown]
# ## 🔀 If-Else

# %%
# Übung 6: Bedingungen
alter = 20

if alter >= 18:
    print("Volljährig")
else:
    print("Minderjährig")

# Mit elif
punkte = 85

if punkte >= 90:
    note = "Sehr gut"
elif punkte >= 80:
    note = "Gut"
elif punkte >= 70:
    note = "Befriedigend"
else:
    note = "Nicht bestanden"

print(f"Note: {note}")

# %% [markdown]
# ### ✏️ Deine Aufgabe:
# Schreibe ein Programm das prüft ob eine Zahl positiv, negativ oder null ist.

# %%
# Dein Code hier:
zahl = -5
# ...

# %% [markdown]
# ## 🔁 Schleifen

# %%
# Übung 7: for-Schleife
for i in range(5):
    print(f"Durchlauf {i}")

# Über Liste
namen = ["Max", "Anna", "Tom"]
for name in namen:
    print(f"Hallo {name}!")

# %%
# Übung 8: while-Schleife
zahl = 1
while zahl <= 5:
    print(zahl)
    zahl += 1

# %% [markdown]
# ### ✏️ Deine Aufgabe:
# Schreibe eine Schleife die alle geraden Zahlen von 2 bis 20 ausgibt.

# %%
# Dein Code hier:

# %% [markdown]
# ## 🔧 Funktionen

# %%
# Übung 9: Funktionen
def begruesse(name):
    print(f"Hallo {name}!")

begruesse("Max")
begruesse("Anna")

# Mit Return
def addiere(a, b):
    return a + b

ergebnis = addiere(5, 3)
print(f"5 + 3 = {ergebnis}")

# %% [markdown]
# ### ✏️ Deine Aufgabe:
# Schreibe eine Funktion `ist_gerade(zahl)` die True zurückgibt wenn die Zahl gerade ist.

# %%
# Dein Code hier:
def ist_gerade(zahl):
    # ...
    pass

# Test
print(ist_gerade(4))  # True
print(ist_gerade(7))  # False

# %% [markdown]
# ## 🎯 Projekt: Mini-Rechner
#
# Erstelle einen einfachen Taschenrechner mit Funktionen für +, -, *, /

# %%
# Dein Rechner:
def addiere(a, b):
    return a + b

def subtrahiere(a, b):
    return a - b

# ... Vervollständige!

# Test
print(f"10 + 5 = {addiere(10, 5)}")
print(f"10 - 5 = {subtrahiere(10, 5)}")

# %% [markdown]
# ## 🎉 Glückwunsch!
#
# Du hast die Grundlagen durchgearbeitet! Weiter so! 🚀
